# %%
# Import the pathlib and csv library
from pathlib import Path
import csv

# %%
# Set the file path
csvpath_menu = Path("Resources/menu_data.csv")
csvpath_sales = Path("Resources/sales_data.csv")

# %%
# Initialize a variable to hold Profit/Losses
menu = []
sales = []

# Initialize line number variable
line_num_menu=0
line_num_sales=0

# Open the menu csv file as an object
with open(csvpath_menu, "r") as csvfile_menu:
    
    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
    csvreader = csv.reader(csvfile_menu, delimiter=",")

    # Read the header row first
    csv_header = next(csvreader)
    line_num_menu +=1
 
    # Append pnl list with 
    for row in csvreader:
        menu_item = (row)
        menu.append(menu_item)
        
# Open the sales csv file as an object
with open(csvpath_sales, "r") as csvfile_sales:
    
    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
    csvreader = csv.reader(csvfile_sales, delimiter=",")

    # Read the header row first
    csv_header_sales = next(csvreader)
    line_num_sales +=1
 
    # Append pnl list with 
    for row in csvreader:
        sales_item = (row)
        sales.append(sales_item)

# %%
# Initialize dictionary
report = {}

count_sales = 0

quantity = 0
sales_item = ""

item = ""
price = 0
cost = 0

def calc_profit(quantity, price, cost):
    profit = quantity * (price - cost)
    return profit


for row in sales:
    quantity = int(row[3])
    menu_item = row[4]
    count_sales += 1
    if sales_item not in report.items():
        report = {"01-count": 0, "02-revenue": 0, "03-cogs": 0, "04-profit": 0, "sales_item": ""}
       
    
for row in menu:
    item = str(row[0])
    price = (row[3])
    cost = int(row[4])
    if sales_item == item:
        profit = calc_proft(quantity, price, cost)
        report[sales_item]["01-count"] += quantity
        report[sales_item]["02-revenue"] += price * quantity
        report[sales_item]["03-cogs"] += cost * quantity
        report[sales_item]["04-profit"] += profit * quantity
    else:
        print(f"{sales_item} does not equal {item}! NO MATCH!")
        
#I'm now confused
# Out:
#  does not equal edamame! NO MATCH!
#  does not equal house salad! NO MATCH!
#  does not equal cucumber sunomono salad! NO MATCH!
#  does not equal hiyashi wakame seaweed salad! NO MATCH!
#  does not equal agedashi tofu! NO MATCH!
#  does not equal hiyayakko tofu! NO MATCH!
#  does not equal pork floss bao! NO MATCH!
#  does not equal kakuni bao! NO MATCH!
#  does not equal edamame fried gyoza (vegan)! NO MATCH!
#  does not equal fried gyoza! NO MATCH!
#  does not equal takoyaki! NO MATCH!
#  does not equal rock shrimp tempura! NO MATCH!
#  does not equal soft-shell crab tempura! NO MATCH!
#  does not equal ebi katsu shrimp bao! NO MATCH!
#  does not equal nagomi shoyu! NO MATCH!
#  does not equal shio ramen! NO MATCH!
#  does not equal spicy miso ramen! NO MATCH!
#  does not equal vegetarian spicy miso! NO MATCH!
#  does not equal miso crab ramen! NO MATCH!
#  does not equal soft-shell miso crab ramen! NO MATCH!
#  does not equal tori paitan ramen! NO MATCH!
# ...
